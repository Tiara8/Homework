# %%
if age >= 25:
    print("Renting a car is more affordable")
    
if age < 25:
    print("Renting a car is very expensive.")
    

if age >= 25:
    print("Renting a car is more affordable.")

else : 
    if 18 < age < 25:
        print("Renting a car is very expensive.")
        
    if age < 18:
        print("You cannot legally rent a car.")

# %%
sent1 = "The quick brown fox jumps over the lazy dog"
count = 0

for char in sent1:
    count += 1    
print(count)

for vowels in sent1:
    if vowels in "aeiou" :
        print("The vowels in sent1 are ", vowels) 
        
        
couture = ["trousers", "blouse", "bandana", "cumber band", "blazer", "vest", "french beret", "scarf", "stole"] 

panettone = {"cerise", "fuchsia", "aqua", "maple", "auburn", "burnt sienna", "gunmetal blue", "Dark Sapphire"}

for x in couture:
    for y in panettone:
        print(x,y)

      
print(sum(range(1, 100)))    
           
fruitList = ["apple", "banana", "cherry"]
print(fruitList[1]) 

fruitList[0] = "kiwi"

fruitList.append("orange")
print(fruitList)

fruitList.insert(1, "lemon")
print(fruitList)

fruitList.remove("banana")
print(fruitList)

fruitList2 = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
print(fruitList2[3])
print(fruitList2[-2])

print(fruitList2[2:5])

print(len(fruitList2))

fruitList2.sort(reverse=True)
print(fruitList2)
# Out:
# 43
# The vowels in sent1 are  e
# The vowels in sent1 are  u
# The vowels in sent1 are  i
# The vowels in sent1 are  o
# The vowels in sent1 are  o
# The vowels in sent1 are  u
# The vowels in sent1 are  o
# The vowels in sent1 are  e
# The vowels in sent1 are  e
# The vowels in sent1 are  a
# The vowels in sent1 are  o
# trousers fuchsia
# trousers maple
# trousers cerise
# trousers auburn
# trousers Dark Sapphire
# trousers gunmetal blue
# trousers aqua
# trousers burnt sienna
# blouse fuchsia
# blouse maple
# blouse cerise
# blouse auburn
# blouse Dark Sapphire
# blouse gunmetal blue
# blouse aqua
# blouse burnt sienna
# bandana fuchsia
# bandana maple
# bandana cerise
# bandana auburn
# bandana Dark Sapphire
# bandana gunmetal blue
# bandana aqua
# bandana burnt sienna
# cumber band fuchsia
# cumber band maple
# cumber band cerise
# cumber band auburn
# cumber band Dark Sapphire
# cumber band gunmetal blue
# cumber band aqua
# cumber band burnt sienna
# blazer fuchsia
# blazer maple
# blazer cerise
# blazer auburn
# blazer Dark Sapphire
# blazer gunmetal blue
# blazer aqua
# blazer burnt sienna
# vest fuchsia
# vest maple
# vest cerise
# vest auburn
# vest Dark Sapphire
# vest gunmetal blue
# vest aqua
# vest burnt sienna
# french beret fuchsia
# french beret maple
# french beret cerise
# french beret auburn
# french beret Dark Sapphire
# french beret gunmetal blue
# french beret aqua
# french beret burnt sienna
# scarf fuchsia
# scarf maple
# scarf cerise
# scarf auburn
# scarf Dark Sapphire
# scarf gunmetal blue
# scarf aqua
# scarf burnt sienna
# stole fuchsia
# stole maple
# stole cerise
# stole auburn
# stole Dark Sapphire
# stole gunmetal blue
# stole aqua
# stole burnt sienna
# 4950
# banana
# ['kiwi', 'banana', 'cherry', 'orange']
# ['kiwi', 'lemon', 'banana', 'cherry', 'orange']
# ['kiwi', 'lemon', 'cherry', 'orange']
# orange
# melon
# ['cherry', 'orange', 'kiwi']
# 7
# ['orange', 'melon', 'mango', 'kiwi', 'cherry', 'banana', 'apple']
